# %%
import sys
import os
import glob
from pathlib import Path
import random
from tqdm.notebook import tqdm
import numpy as np
import pandas as pd

from sklearn.metrics import confusion_matrix, accuracy_score, precision_recall_fscore_support, roc_curve, roc_auc_score

import torch
import torch.nn as nn
import torch.nn.functional as F
from transformers import AutoConfig
from transformers import AutoTokenizer, Trainer, TrainingArguments
from transformers import AutoModelForSequenceClassification, DataCollatorWithPadding
# Out:
# WARNING:tensorflow:From c:\Users\nishigaki\研究\radnlp\env_radnlp\Lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
# Configurations
class CFG:
    SEED = 0
    VALID_DATA_PATH = Path('../../radnlp_2024_train_val_20240731/ja/main_task/val')
    MODEL_SAVE_PATH = Path('./model')
    MODEL_NAME = 'debarta'
    MODEL_PATH = 'microsoft/deberta-v3-large'
    # MODEL_NAME = 'globis-university/deberta-v3-japanese-large'
    # MODEL_PATH = 'globis-university/deberta-v3-japanese-large'
    MAX_LENGTH = 512

# %%
def get_device() -> str:
    """
    Returns the best available device for PyTorch computations.
    """
    if torch.backends.mps.is_available():
        # macOS with Apple Silicon (MPS backend)
        return "mps"
    elif torch.cuda.is_available():
        # NVIDIA GPU
        return "cuda"
    else:
        # Fallback to CPU
        return "cpu"

try:
    device = torch.device(get_device())
    print(f"Using device: {device}")
except RuntimeError as e:
    print(f"Failed to initialize the device: {e}")
    device = torch.device("cpu")  # Fallback to CPU in case of an error
# Out:
# Using device: cuda

# %%
def seed_everything(seed):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False #Trueで高速化重視, Falseで再現性重視
seed_everything(CFG.SEED)
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
torch.set_num_threads(1)

# %%
def convert_list(text_list, label_dic):
    """
    リストのテキストを、指定された辞書に基づいて数値に変換します。

    Args:
        text_list (list): 変換したいテキストのリスト
        label_dic (dict): テキストと対応する数値の辞書

    Returns:
        list: 数値に変換されたリスト
    """

    num_list = []
    for text in text_list:
        # 辞書から対応する数値を取得
        num = label_dic.get(text, None)
        if num is not None:
            num_list.append(num)
        else:
            print(f"対応する数値が見つかりません: {text}")
    return num_list

label_dic_t = {'T0':0, 'Tis':1, 'T1mi':2, 'T1a':3, 'T1b':4, 'T1c':5, 'T2a':6, 'T2b':7, 'T3':8, 'T4':9}
inverse_label_dic_t = {v: k for k, v in label_dic_t.items()}
label_dic_n = {'N0':0, 'N1':1, 'N2':2, 'N3':3}
inverse_label_dic_n = {v: k for k, v in label_dic_n.items()}
label_dic_m = {'M0':0, 'M1a':1, 'M1b':2, 'M1c':3}
inverse_label_dic_m = {v: k for k, v in label_dic_m.items()}

# %%
def create_dataframe(folder_path):
    """
    指定されたフォルダ内のテキストファイルからDataFrameを作成する関数

    Args:
        folder_path (PosixPath): テキストファイルが入っているフォルダのパス

    Returns:
        pandas.DataFrame: 作成されたDataFrame
    """

    # フォルダ内のすべてのテキストファイルのパスを取得
    file_list = list(folder_path.glob('*.txt'))

    # 空のDataFrameを作成
    df_text = pd.DataFrame(columns=['id', 'text'])
    
    # label.csvを読み込む
    df_label = pd.read_csv(os.path.join(folder_path, "label.csv"))

    for file in file_list:
        # ファイル名からIDを抽出
        # file_id = str(file).split("/")[-1].split(".")[0]
        file_id = str(file).split("\\")[-1].split(".")[0] # Windows
        
        # テキストファイルを読み込む
        with open(file, 'r', encoding='utf-8') as f:
            text = f.read()

        # DataFrameに追記
        rows = []
        rows.append({'id': int(file_id), 'text': text})
        df_text = pd.concat([df_text, pd.DataFrame(rows)], ignore_index=True)
        
    # textとlabelのDataFrameを結合
    df = pd.merge(df_text, df_label, on='id', how='left')

    return df

val_df = create_dataframe(CFG.VALID_DATA_PATH)

# %%
val_df.head(10)
# Out:
#          id                                               text    t   n    m
# 0  10365351  左肺中枢側に腫瘤性病変を認めます（103×83×96mm）。原発性肺癌を疑います。左肺の末梢...   T4  N2  M1a
# 1  10376521  右肺に長径 13.7cm 大、胸壁を超える腫瘤を認めます。T4 と考えます。\n縦隔リンパ節...   T4  N2  M1c
# 2  10634640  左上葉に 22mm 大の不整形腫瘤影を認め、肺癌が疑われます。\n縦隔に有意なリンパ節腫大は...  T1c  N0   M0
# 3  10708825  比較可能な画像検査はありません。\n右肺上葉に長径 13.7cm 大の腫瘤影を認めます。腫瘤...   T4  N2  M1c
# 4  10868892  右下葉に 42mm 大の腫瘤を認め、肺癌を疑います。S6 に同一肺葉内の不連続な副腫\n瘍結...   T3  N2  M1c
# 5  11407659  右下葉に 42mm 大の腫瘤影を認め、肺癌が疑われます。\n縦隔に腫大リンパ節を認め、転移が...  T2b  N2  M1c
# 6  11566958  左肺上葉 S3 を中心として  約 3.7cm の  不整形腫瘤性病変を認めます。充実成分を...  T2a  N0   M0
# 7  11726941  左肺門部に辺縁不整な腫瘤を認めます。ご指摘の癌病変と考えます。\n左主気管支は途絶しており、...   T4  N2  M1a
# 8  12023275  比較可能な画像検査はありません。\n右肺下葉に長径 42mm 程度の腫瘤影を認め、既知の肺癌...  T2b  N2  M1c
# 9  12550658  右肺上葉に径 13cm 強の境界明瞭な腫瘤を認めます。癌病変の原発巣と考えます。明\nらかな...   T4  N2  M1c

# %% [markdown]
# # 分類モデルの読み込み

# %%
tokenizer = AutoTokenizer.from_pretrained(CFG.MODEL_PATH)

base_folder = CFG.MODEL_SAVE_PATH / 't'
trained_model_path = [f for f in base_folder.iterdir() if f.is_dir() and "checkpoint-" in f.name][0]
model_t = AutoModelForSequenceClassification.from_pretrained(trained_model_path)

base_folder = CFG.MODEL_SAVE_PATH / 'n'
trained_model_path = [f for f in base_folder.iterdir() if f.is_dir() and "checkpoint-" in f.name][0]
model_n = AutoModelForSequenceClassification.from_pretrained(trained_model_path)

base_folder = CFG.MODEL_SAVE_PATH / 'm'
trained_model_path = [f for f in base_folder.iterdir() if f.is_dir() and "checkpoint-" in f.name][0]
model_m = AutoModelForSequenceClassification.from_pretrained(trained_model_path)
# Out:
# c:\Users\nishigaki\研究\radnlp\env_radnlp\Lib\site-packages\transformers\convert_slow_tokenizer.py:561: UserWarning: The sentencepiece tokenizer that you are converting to a fast tokenizer uses the byte fallback option which is not implemented in the fast tokenizers. In practice this means that the fast version of the tokenizer can produce unknown tokens whereas the sentencepiece version would have converted these unknown tokens into a sequence of byte tokens matching the original piece of text.
#   warnings.warn(

# %%
model_t.eval()
model_n.eval()
model_m.eval()

t_pred_li, n_pred_li, m_pred_li = [], [], []

for i in tqdm(range(len(val_df))):
    tokens = tokenizer.encode_plus(val_df.iloc[i]['text'], padding=False, truncation=True, max_length=CFG.MAX_LENGTH, return_tensors="pt")

    with torch.no_grad():
        t_pred = inverse_label_dic_t.get(F.softmax(model_t(**tokens).logits, dim=1).argmax(dim=1).item(), "Unknown")
        n_pred = inverse_label_dic_n.get(F.softmax(model_n(**tokens).logits, dim=1).argmax(dim=1).item(), "Unknown")
        m_pred = inverse_label_dic_m.get(F.softmax(model_m(**tokens).logits, dim=1).argmax(dim=1).item(), "Unknown")

        t_pred_li.append(t_pred)
        n_pred_li.append(n_pred)
        m_pred_li.append(m_pred)
val_df['t_pred'] = t_pred_li
val_df['n_pred'] = n_pred_li
val_df['m_pred'] = m_pred_li

val_df.to_csv('../model_outputs/debarta_results.csv')
# Out:
#   0%|          | 0/54 [00:00<?, ?it/s]

# %%
val_df
# Out:
#           id                                               text     t   n  \
# 0   10365351  左肺中枢側に腫瘤性病変を認めます（103×83×96mm）。原発性肺癌を疑います。左肺の末梢...    T4  N2
# 1   10376521  右肺に長径 13.7cm 大、胸壁を超える腫瘤を認めます。T4 と考えます。\n縦隔リンパ節...    T4  N2
# 2   10634640  左上葉に 22mm 大の不整形腫瘤影を認め、肺癌が疑われます。\n縦隔に有意なリンパ節腫大は...   T1c  N0
# 3   10708825  比較可能な画像検査はありません。\n右肺上葉に長径 13.7cm 大の腫瘤影を認めます。腫瘤...    T4  N2
# 4   10868892  右下葉に 42mm 大の腫瘤を認め、肺癌を疑います。S6 に同一肺葉内の不連続な副腫\n瘍結...    T3  N2
# 5   11407659  右下葉に 42mm 大の腫瘤影を認め、肺癌が疑われます。\n縦隔に腫大リンパ節を認め、転移が...   T2b  N2
# 6   11566958  左肺上葉 S3 を中心として  約 3.7cm の  不整形腫瘤性病変を認めます。充実成分を...   T2a  N0
# 7   11726941  左肺門部に辺縁不整な腫瘤を認めます。ご指摘の癌病変と考えます。\n左主気管支は途絶しており、...    T4  N2
# 8   12023275  比較可能な画像検査はありません。\n右肺下葉に長径 42mm 程度の腫瘤影を認め、既知の肺癌...   T2b  N2
# 9   12550658  右肺上葉に径 13cm 強の境界明瞭な腫瘤を認めます。癌病変の原発巣と考えます。明\nらかな...    T4  N2
# 10  12646171  両肺に多発する腫瘤を認めます。特に右上葉から中葉にかけて、胸壁浸潤を伴う巨大な腫瘤があり、肺...    T4  N2
# 11  12667350  右肺下葉 S9/10 に最大径 42mm の腫瘤性病変を認めます。原発性肺癌を疑います。胸膜...   T2b  N2
# 12  12890602  右下葉 S6 に 14×15mm 程度の境界明瞭な GGN を認めます。AIS の可能性が否...   Tis  N0
# 13  13138120  左肺尖部に辺縁不整な腫瘤を認めます。長径は 22mm です。既知の肺癌と考えま\nす。胸膜へ...   T1c  N0
# 14  13248038  右肺下葉に最大径 42mm の腫瘤があります。\n肺癌疑います。\n右肺門、同側、対側縦隔リ...   T2b  N3
# 15  13641873  右肺下葉に辺縁不整な腫瘤様の陰影を認めます。内部には壊死状の低吸収域を認めます。ご指摘の癌病...   T2b  N3
# 16  13716139  左肺上葉に長径 2.2cm の結節影を認めます。分葉状の形態あり、辺縁に棘状影が見られます。...   T1c  N0
# 17  14063477  右肺野に長径 13cm を超え、胸壁へと進展する病変を認め、肺癌が疑われます。\n両肺野には...    T4  N0
# 18    147290  左肺門部に 37mm 大の腫瘤影を認め、ご指摘の肺癌が疑われます。\n縦隔に有意なリンパ節腫...   T2a  N0
# 19  14841832  左肺門部に長径 37mm 大の腫瘤を認め、スピクラと内部空洞がみられます。肺癌を疑います。腫...   T2a  N1
# 20  15448681  右肺下葉 S10 に限局した約 1.4ｘ1.5mm のすりガラス上結節を認めます。境界明瞭で...   Tis  N0
# 21  15532322  左上葉には⻑径 22mm 大の不整形結節あり、既知の肺癌部分と思われます。\n病的リンパ節腫...   T1c  N0
# 22   1600422  左肺尖部に⻑径 22mm の不整形腫瘤を認め、既知肺癌に相当の病変と思われます。その他、肺野...   T1c  N0
# 23  16066820  左肺上葉に最大径 22mm  の分葉状腫瘤があります。\n一部胸膜陥入像を伴っています。\n...   T1c  N0
# 24  16191878  比較可能な画像検査はありません。\n右肺下葉  S10 に 1.5cm×1.4cm  程度の...   Tis  N0
# 25  16572985  右下葉に 15mm 大の pure GGN を認めます。ご指摘の肺癌病変が疑われます。\n縦...   Tis  N0
# 26   2318717  右下葉に長径 15mm 大の mixed GGO を認めます。肺腺癌を否定できません。\n右...  T1mi  N0
# 27    241752  右下葉に 14×15mm  の限局性すりガラス影があります。\n粗大な充実部分は認めません。...   Tis  N0
# 28   2737981  左肺尖部に分葉状腫瘤性病変を認めます。最大径は 22mm です。原発性肺癌を疑い\nます。\...    T3  N0
# 29   2755461  左上葉に最大径 103mm の境界不明瞭な増強効果の乏しい腫瘤があります。\n肺癌と考えます...    T4  N2
# 30   3162670  左肺門部に肺門部、縦隔リンパ節と一塊となった腫瘤を認め、肺癌を疑います。\n左主気管支は閉塞...    T4  N2
# 31   3462779  左肺には縦隔浸潤が疑われる腫瘤があり、左肺全体に及ぶ無気肺を伴っています。\n肺門-気管分岐...    T4  N2
# 32   4592263  右肺下葉にすりガラス状結節を認めます。横径 14×15mm です。境界明瞭で分葉状を呈してい...   Tis  N0
# 33   4644984  右下葉に腫瘤を認め、既知肺癌を疑います。\n右縦隔、肺門部に軟部影を認め、リンパ節転移を疑い...    T0  N2
# 34   4660316  左肺肺門部に長径 10.3cm の腫瘤を認めます。左肺は閉塞性無気肺となっています。肺動脈主...    T4  N2
# 35   4724041  左肺門部、左上葉 S2 に主座を置く⻑径 37mm の不整形腫瘤を認め、内部に空洞形成\nを...   T2a  N0
# 36   4734929  左舌区から下葉にまたがる 37mm の空洞性腫瘤あり、既知の肺癌と思われます。\n縦隔リンパ...   T2a  N0
# 37   4924173  右肺下葉 S10 に長径 1.5cm のすりガラス状結節を認め、既知の肺腺癌を疑います。\n...   Tis  N0
# 38   5180986  比較可能な画像検査はありません。\n扁平上皮癌が知られています。\n左主気管支から末梢側は閉...    T4  N2
# 39   5764772  右下葉 S10 に⻑径 15mm の pure GGN を認めます。既知肺癌に相当の病変と思...   Tis  N0
# 40   5888093  左肺門部に⻑径 103mm の腫瘤を認め、原発性肺癌を疑います。左主気管支は腫瘍浸潤による閉...    T4  N3
# 41   6238897  左肺門部に軟部影を認め、肺癌が疑われます。縦隔内へと進展し、左主気管支は腫瘍により閉塞してお...    T4  N0
# 42   6278112  右上葉に⻑径 137mm の巨大腫瘤を認め、原発性肺癌を疑います。胸壁、肋骨に浸潤\nしてい...    T4  N3
# 43   6311491  左上葉背側に spicula  を伴う 37mm  の空洞性病変があります。\n左上葉気管支...   T2a  N1
# 44   6688795  比較可能な画像検査はありません。\n左肺上葉の肺門部に長径 37mm  程度の分葉状の腫瘤を...   T2a  N1
# 45   6831979  両肺には多数の円形腫瘤が認められます。右肺の 137mm のものが最大で、胸壁や肋骨への浸潤...    T4  N3
# 46   7859648  右下葉には不整形の腫瘤影があり、既知の肺癌原発巣が疑われます(最大径 42mm)。\n同側肺...   T2b  N2
# 47   7883310  左上葉に 22mm 大の分葉状の不整形結節を認め、肺癌を疑います。\nその他、肺野に明らかな...   T1c  N0
# 48   8370801  右肺上葉、中葉に広がる約 13cm の腫瘍性病変を疑います。原発性肺癌を疑います。胸壁に浸潤...    T4  N2
# 49   8450208  比較可能な画像検査はありません。\n左肺上区  S1＋2 に長径 22mm  程度の分葉状の...   T1c  N0
# 50    876951  左肺上葉背側を主体に、葉間胸膜をまたいで下葉にも突出する長径 37mm の腫瘤を認めます。辺...   T2a  N0
# 51   8977151  右下葉に長径 4.2cm 大の腫瘤を認め肺癌を疑います。無気肺も伴っています。腫瘤近傍の胸壁...    T3  N2
# 52    923073  左肺上葉に長径 3.7 ㎝の腫瘤影を認めます。分葉状の形態あり、周囲に棘状影も見られ原発性肺...   T2a  N0
# 53   9815314  右下葉に最大径 137mm  の腫瘤性病変があります。\n病変は肋間を越えて胸壁に直接浸潤が...    T4  N2
#
#       m t_pred n_pred m_pred
# 0   M1a     T4     N2    M1c
# 1   M1c     T4     N2    M1c
# 2    M0    T2b     N0     M0
# 3   M1c     T4     N2    M1c
# 4   M1c     T3     N2    M1c
# 5   M1c    T2b     N2    M1c
# 6    M0     T4     N0     M0
# 7   M1a     T4     N2     M0
# 8   M1c    T2b     N2    M1c
# 9   M1c     T3     N2    M1c
# 10  M1c     T4     N2    M1c
# 11  M1c    T2b     N2    M1c
# 12   M0    T1c     N0     M0
# 13   M0    T2b     N0     M0
# 14  M1c     T4     N2    M1c
# 15  M1c     T3     N2    M1c
# 16   M0     T4     N0     M0
# 17  M1c     T3     N2    M1c
# 18   M0    T2b     N0    M1c
# 19   M0     T4     N2    M1c
# 20   M0    T1c     N0     M0
# 21   M0    T2b     N0     M0
# 22   M0     T4     N0     M0
# 23   M0    T2b     N0     M0
# 24   M0    T1c     N0     M0
# 25   M0    T1c     N0     M0
# 26   M0    T1c     N0     M0
# 27   M0    T1c     N0     M0
# 28   M0     T4     N0     M0
# 29  M1a     T4     N2    M1c
# 30  M1a     T4     N2    M1c
# 31  M1a     T4     N2     M0
# 32   M0    T2a     N0     M0
# 33  M1c     T4     N2    M1c
# 34  M1a     T4     N2    M1c
# 35   M0     T4     N0     M0
# 36   M0    T2b     N0     M0
# 37   M0    T2a     N0     M0
# 38  M1a     T4     N2     M0
# 39   M0    T2a     N0    M1c
# 40  M1a     T4     N2     M0
# 41  M1a     T4     N0     M0
# 42  M1c     T3     N2    M1c
# 43   M0     T4     N2     M0
# 44   M0     T4     N2    M1c
# 45  M1c     T3     N2    M1c
# 46  M1c    T2b     N2     M0
# 47   M0    T2b     N0     M0
# 48  M1c     T4     N2    M1c
# 49   M0    T1c     N0     M0
# 50   M0    T2b     N0    M1c
# 51  M1c     T3     N2    M1c
# 52   M0     T4     N0     M0
# 53  M1c     T4     N2    M1c

# %% [markdown]
# # Submission CSVの出力

# %%
sub_df = pd.read_csv('../model_outputs/debarta_results.csv')
t_pred = sub_df['t_pred'].values.tolist()
n_pred = sub_df['n_pred'].values.tolist()
m_pred = sub_df['m_pred'].values.tolist()
t_label = sub_df['t'].values.tolist()
n_label = sub_df['n'].values.tolist()
m_label = sub_df['m'].values.tolist()

print(f't_acc: {accuracy_score(t_label, t_pred)}')
print(f'n_acc: {accuracy_score(n_label, n_pred)}')
print(f'm_acc: {accuracy_score(m_label, m_pred)}')
# Out:
# t_acc: 0.3888888888888889
# n_acc: 0.8333333333333334
# m_acc: 0.7222222222222222

# %%
sub_df = pd.read_csv('../model_outputs/debarta_results.csv')
select_df = sub_df[['id', 't_pred', 'n_pred', 'm_pred']]
rename_df = select_df.rename(columns={'t_pred': 't', 'n_pred': 'n', 'm_pred': 'm'})
rename_df.to_csv('../model_outputs/submission_debarta.csv', index=False)

# %%
rename_df.head(10)
# Out:
#          id    t   n    m
# 0  10365351   T4  N2  M1c
# 1  10376521   T4  N2  M1c
# 2  10634640  T2b  N0   M0
# 3  10708825   T4  N2  M1c
# 4  10868892   T3  N2  M1c
# 5  11407659  T2b  N2  M1c
# 6  11566958   T4  N0   M0
# 7  11726941   T4  N2   M0
# 8  12023275  T2b  N2  M1c
# 9  12550658   T3  N2  M1c

# %%
print(rename_df['t'].value_counts())
print(rename_df['n'].value_counts())
print(rename_df['m'].value_counts())
# Out:
# t
# T4     25
# T2b    12
# T3      7
# T1c     7
# T2a     3
# Name: count, dtype: int64
# n
# N2    29
# N0    25
# Name: count, dtype: int64
# m
# M0     28
# M1c    26
# Name: count, dtype: int64
